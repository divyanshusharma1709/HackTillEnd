# %%
from lxml import html

# %%
import requests 
page = requests.get("https://www.google.com/search?source=hp&ei=kWLAW_aYEome9QOEhaugAw&q=harshita+diddee&oq=HARS&gs_l=psy-ab.3.0.35i39k1j0i67k1l8j0i20i263k1.965.1651.0.2803.5.4.0.0.0.0.213.422.2-2.2.0....0...1c.1.64.psy-ab..3.2.420.0...0.kZNSM90rrBA")
print(page.content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><noscript><meta content="0;url=/search?q=harshita+diddee&amp;ie=UTF-8&amp;gbv=1&amp;sei=CWPAW5XSOZrd9QPhz7CQCw" http-equiv="refresh"><style>table,div,span,p{display:none}</style><div style="display:block">Please click <a href="/search?q=harshita+diddee&amp;ie=UTF-8&amp;gbv=1&amp;sei=CWPAW5XSOZrd9QPhz7CQCw">here</a> if you are not redirected within a few seconds.</div></noscript><title>harshita diddee - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gb
# ...

# %%
from bs4 import BeautifulSoup as BS

# %%
soup = BS(page.content, 'html.parser')
list_src=[item["href"] for item in soup.find_all('a') if "href" in item.attrs]
# soup2 = BS(page2.content, 'html.parser')
# list_src2=[item["src"] for item in soup.find_all('img') if "src" in item.attrs]
# soup3 = BS(page3.content, 'html.parser')
# list_src3=[item["src"] for item in soup.find_all('img') if "src" in item.attrs]

# %%
len(list_src)
# Out:
# 63

# %%
list_src
# Out:
# ['/search?q=harshita+diddee&ie=UTF-8&gbv=1&sei=CWPAW5XSOZrd9QPhz7CQCw',
#  'https://www.google.co.in/search?hl=en&tbm=isch&source=og&tab=wi',
#  'https://maps.google.co.in/maps?hl=en&tab=wl',
#  'https://play.google.com/?hl=en&tab=w8',
#  'https://www.youtube.com/results?gl=IN&tab=w1',
#  'https://news.google.co.in/nwshp?hl=en&tab=wn',
#  'https://mail.google.com/mail/?tab=wm',
#  'https://drive.google.com/?tab=wo',
#  'https://www.google.co.in/intl/en/options/',
#  'http://www.google.co.in/history/optout?hl=en',
#  '/preferences?hl=en',
#  'https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=https://www.google.com/search%3Fsource%3Dhp%26ei%3DkWLAW_aYEome9QOEhaugAw%26q%3Dharshita%2Bdiddee%26oq%3DHARS%26gs_l%3Dpsy-ab.3.0.35i39k1j0i67k1l8j0i20i263k1.965.1651.0.2803.5.4.0.0.0.0.213.422.2-2.2.0....0...1c.1.64.psy-ab..3.2.420.0...0.kZNSM90rrBA',
#  '/webhp?hl=en-IN',
# ...

# %%
dict_update={"Harshita Diddee":list_src}

# %%
print(dict_update)
# Out:
# {'Harshita Diddee': ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjmdTpYv62sB4BdyFhLR7zumgyHmi8IgaicIOg6mXyz8Sd_wKONpf11kw', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbd1x5fxFYY1sYqtpilx3af1lUABa98R2PetqsGY_U8wTdzqzZzUXmsiE', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrrD0Es9eruZ9EUEQxYNlvazBwnDwoUap3-2vvR1h-BpS0TAOU45HHPA', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdu75CKKdzdLCMtDA2hfJ7tjlm6NKIcjmp77zd8jhXb3WTqBBPvb9Z6A', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzCePIUw0SUMU6CvZE5aylgVB_FjaI6fnGuleTIyFFQDNHHaCpKRzo-8c', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-4zVakB4WQK5dkxkPpSUzZib5LpwZjLTBr0IZR0dAcCR4ahlLUm-dPg', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ2LesVjW37apjCdklp3y4B5SUewif2Xwve9XzuEP0lbvwxpRrrdXi3Gg', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTP4xVczNM4P-6Ar6kG1Q78mXgukgEOsxFdwDmFePQBb5pDKQyX6lS0ZoE', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT400AA
# ...
